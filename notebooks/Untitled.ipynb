# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)
df["species"] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
print("h")
# Out:
# h

# %%
from jupyter_server.serverapp import ServerApp
print(ServerApp().iopub_data_rate_limit)

# %%
import jupyterlab_pywalker_renderer.formatter as f                                                        
print(hasattr(f, 'MAX_INLINE_ROWS'))  # Should print False
# Out:
# False

# %%
import pygwalker as pyg
walker = pyg.walk(df)
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00064e77c1ea8334RWHm4TaeCvV6bDY1" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00064e77c1ea8334RWHm4TaeCvV6bDY1") {
#             var iframe = document.getElementById("gwalker-00064e77c1ea8334RWHm4TaeCvV6bDY1");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
